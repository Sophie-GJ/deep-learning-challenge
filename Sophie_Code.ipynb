# %% [markdown]
# <a href="https://colab.research.google.com/github/Sophie-GJ/deep-learning-challenge/blob/main/Sophie_Code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd
df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# ...

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
df = df.drop(['EIN', 'NAME'], axis = 1)
df
# Out:
#       APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0                  T10       Independent          C1000    ProductDev
# 1                   T3       Independent          C2000  Preservation
# 2                   T5  CompanySponsored          C3000    ProductDev
# 3                   T3  CompanySponsored          C2000  Preservation
# 4                   T3       Independent          C1000     Heathcare
# ...                ...               ...            ...           ...
# 34294               T4       Independent          C1000    ProductDev
# 34295               T4  CompanySponsored          C3000    ProductDev
# 34296               T3  CompanySponsored          C2000  Preservation
# 34297               T5       Independent          C3000    ProductDev
# 34298               T3       Independent          C1000  Preservation
#
#        ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS   ASK_AMT  \
# ...

# %%
# Determine the number of unique values in each column.
df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
app_types = df['APPLICATION_TYPE'].value_counts()
app_types
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
cutoff = 450
apps = df['APPLICATION_TYPE'].value_counts()
application_types_to_replace = apps[apps > cutoff].index

# Replace in dataframe
for app in application_types_to_replace:
    df['APPLICATION_TYPE'] = df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
df['APPLICATION_TYPE'].value_counts()
# Out:
# Other    34023
# T9         156
# T13         66
# T12         27
# T2          16
# T25          3
# T14          3
# T29          2
# T15          2
# T17          1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
df['CLASSIFICATION' ].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
lower_limit = 1
app_class = df['CLASSIFICATION'].value_counts()
big_classes = app_class[app_class > lower_limit]
big_classes
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
class_cutoff = 1000
classes = df['APPLICATION_TYPE'].value_counts()
classifications_to_replace = app_class[app_class > class_cutoff].index

# Replace in dataframe
for cls in classifications_to_replace:
   df['CLASSIFICATION'] = df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure binning was successful
df['CLASSIFICATION'].value_counts()
# Out:
# Other    32038
# C7000      777
# C1700      287
# C4000      194
# C5000      116
#          ...
# C4120        1
# C8210        1
# C1245        1
# C2561        1
# C2150        1
# Name: CLASSIFICATION, Length: 67, dtype: int64

# %%
df
# Out:
#       APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0                Other       Independent          Other    ProductDev
# 1                Other       Independent          Other  Preservation
# 2                Other  CompanySponsored          Other    ProductDev
# 3                Other  CompanySponsored          Other  Preservation
# 4                Other       Independent          Other     Heathcare
# ...                ...               ...            ...           ...
# 34294            Other       Independent          Other    ProductDev
# 34295            Other  CompanySponsored          Other    ProductDev
# 34296            Other  CompanySponsored          Other  Preservation
# 34297            Other       Independent          Other    ProductDev
# 34298            Other       Independent          Other  Preservation
#
#        ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS   ASK_AMT  \
# ...

# %%
# Convert categorical data to numeric with `pd.get_dummies`
dummy_df = pd.get_dummies(df[['APPLICATION_TYPE', 'AFFILIATION', 'CLASSIFICATION', 'USE_CASE', 'ORGANIZATION', 'INCOME_AMT', 'SPECIAL_CONSIDERATIONS']])
combined_df = pd.concat([df, dummy_df], axis=1)
combined_df
# Out:
#       APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0                Other       Independent          Other    ProductDev
# 1                Other       Independent          Other  Preservation
# 2                Other  CompanySponsored          Other    ProductDev
# 3                Other  CompanySponsored          Other  Preservation
# 4                Other       Independent          Other     Heathcare
# ...                ...               ...            ...           ...
# 34294            Other       Independent          Other    ProductDev
# 34295            Other  CompanySponsored          Other    ProductDev
# 34296            Other  CompanySponsored          Other  Preservation
# 34297            Other       Independent          Other    ProductDev
# 34298            Other       Independent          Other  Preservation
#
#        ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS   ASK_AMT  \
# ...

# %%
combined_df = combined_df.drop(['APPLICATION_TYPE', 'AFFILIATION', 'CLASSIFICATION', 'USE_CASE', 'ORGANIZATION', 'INCOME_AMT', 'SPECIAL_CONSIDERATIONS'], axis=1)
combined_df
# Out:
#        STATUS   ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  \
# 0           1      5000              1                       1
# 1           1    108590              1                       1
# 2           1      5000              0                       1
# 3           1      6692              1                       1
# 4           1    142590              1                       1
# ...       ...       ...            ...                     ...
# 34294       1      5000              0                       1
# 34295       1      5000              0                       1
# 34296       1      5000              0                       1
# 34297       1      5000              1                       1
# 34298       1  36500179              0                       1
#
#        APPLICATION_TYPE_T12  APPLICATION_TYPE_T13  APPLICATION_TYPE_T14  \
# 0                         0                     0                     0
# ...

# %%
# Split our preprocessed data into our features and target arrays
y = combined_df['IS_SUCCESSFUL'].values
X = combined_df.drop(['IS_SUCCESSFUL'], 1).values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=7)
# Out:
# <ipython-input-12-7e1202bc001f>:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   X = combined_df.drop(['IS_SUCCESSFUL'], 1).values

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
input_features = len(X_train[0])
hidden_nodes1 = 4
hidden_nodes2 = 15
hidden_nodes3 = 5

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(
    tf.keras.layers.Dense(units=hidden_nodes1, input_dim=input_features, activation="relu")
)

# Second hidden layer
nn.add(
    tf.keras.layers.Dense(units=hidden_nodes2, input_dim=input_features, activation="relu")
)

# Third hidden layer
nn.add(
    tf.keras.layers.Dense(units=hidden_nodes3, input_dim=input_features, activation="relu")
)

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_33 (Dense)            (None, 4)                 424
#
#  dense_34 (Dense)            (None, 15)                75
#
#  dense_35 (Dense)            (None, 5)                 80
#
#  dense_36 (Dense)            (None, 1)                 6
#
# ...
# Total params: 585 (2.29 KB)
# Trainable params: 585 (2.29 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
model = nn.fit(X_train_scaled,y_train,epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.6230 - accuracy: 0.6740
# Epoch 2/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5959 - accuracy: 0.6967
# Epoch 3/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5935 - accuracy: 0.6976
# Epoch 4/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5928 - accuracy: 0.6997
# Epoch 5/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5921 - accuracy: 0.6988
# Epoch 6/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5918 - accuracy: 0.6997
# Epoch 7/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5914 - accuracy: 0.6997
# Epoch 8/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5914 - accuracy: 0.6998
# Epoch 9/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5912 - accuracy: 0.6999
# Epoch 10/100
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.5943 - accuracy: 0.6964 - 582ms/epoch - 2ms/step
# Loss: 0.5942882895469666, Accuracy: 0.6964431405067444

# %%
# Export our model to HDF5 file
nn.save("AlphabetSoupCharity.h5")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
